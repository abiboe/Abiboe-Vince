# %% [markdown]
# <a href="https://colab.research.google.com/github/abiboe/Abiboe-Vince/blob/master/tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <a align="left" href="https://ultralytics.com/yolov5" target="_blank">
# <img width="1024", src="https://user-images.githubusercontent.com/26833433/125273437-35b3fc00-e30d-11eb-9079-46f313325424.png"></a>
#
# This is the **official YOLOv5 🚀 notebook** by **Ultralytics**, and is freely available for redistribution under the [GPL-3.0 license](https://choosealicense.com/licenses/gpl-3.0/).
# For more information please visit https://github.com/ultralytics/yolov5 and https://ultralytics.com. Thank you!

# %% [markdown]
# # Setup
#
# Clone repo, install dependencies and check PyTorch and GPU.

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v6.1-177-gd059d1d torch 1.11.0+cu113 CUDA:0 (Tesla K80, 11441MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 38.2/78.2 GB disk)

# %% [markdown]
# # 1. Inference
#
# `detect.py` runs YOLOv5 inference on a variety of sources, downloading models automatically from the [latest YOLOv5 release](https://github.com/ultralytics/yolov5/releases), and saving results to `runs/detect`. Example inference sources are:
#
# ```shell
# python detect.py --source 0  # webcam
#                           img.jpg  # image
#                           vid.mp4  # video
#                           path/  # directory
#                           path/*.jpg  # glob
#                           'https://youtu.be/Zgi9g1ksQHc'  # YouTube
#                           'rtsp://example.com/media.mp4'  # RTSP, RTMP, HTTP stream
# ```

# %%
# !python detect.py --weights runs/train/exp/weights/best.pt --img 640 --conf 0.25 --source ../video.mp4
# Out:
# detect: weights=['runs/train/exp/weights/best.pt'], source=../video.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-177-gd059d1d torch 1.11.0+cu113 CUDA:0 (Tesla K80, 11441MiB)
#
# Fusing layers...
# Model summary: 213 layers, 7018216 parameters, 0 gradients, 15.8 GFLOPs
# video 1/1 (1/3465) /content/video.mp4: 480x640 Done. (0.029s)
# video 1/1 (2/3465) /content/video.mp4: 480x640 Done. (0.029s)
# video 1/1 (3/3465) /content/video.mp4: 480x640 Done. (0.029s)
# video 1/1 (4/3465) /content/video.mp4: 480x640 Done. (0.029s)
# video 1/1 (5/3465) /content/video.mp4: 480x640 Done. (0.026s)
# video 1/1 (6/3465) /content/video.mp4: 480x640 4 without_helmets, 1 triples, Done. (0.026s)
# video 1/1 (7/3465) /content/video.mp4: 480x640 4 without_helmets, 1 triples, Done. (0.026s)
# video 1/1 (8/3465) /content/video.mp4: 480x640 4 without_helmets, 1 triples, Done. (0.026s)
# video 1/1 (9/3465) /content/video.mp4: 480x640 4 without_helmets, 1 triples, Done. (0.025s)
# video 1/1 (10/3465) /content/video.mp4: 480x640 4 without_helmets, 1 triples, Done. (0.024s)
# video 1/1 (11/3465) /content/video.mp4: 480x640 2 without_helmets, Done. (0.024s)
# video 1/1 (12/3465) /content/video.mp4: 480x640 2 without_helmets, Done. (0.024s)
# video 1/1 (13/3465) /content/video.mp4: 480x640 2 without_helmets, Done. (0.024s)
# video 1/1 (14/3465) /content/video.mp4: 480x640 2 without_helmets, 1 triples, Done. (0.023s)
# video 1/1 (15/3465) /content/video.mp4: 480x640 2 without_helmets, Done. (0.023s)
# video 1/1 (16/3465) /content/video.mp4: 480x640 2 without_helmets, Done. (0.023s)
# video 1/1 (17/3465) /content/video.mp4: 480x640 3 without_helmets, Done. (0.023s)
# video 1/1 (18/3465) /content/video.mp4: 480x640 3 without_helmets, Done. (0.023s)
# video 1/1 (19/3465) /content/video.mp4: 480x640 3 without_helmets, Done. (0.022s)
# video 1/1 (20/3465) /content/video.mp4: 480x640 4 without_helmets, Done. (0.022s)
# video 1/1 (21/3465) /content/video.mp4: 480x640 4 without_helmets, Done. (0.022s)
# video 1/1 (22/3465) /content/video.mp4: 480x640 3 without_helmets, Done. (0.022s)
# video 1/1 (23/3465) /content/video.mp4: 480x640 3 without_helmets, Done. (0.022s)
# video 1/1 (24/3465) /content/video.mp4: 480x640 3 without_helmets, Done. (0.021s)
# video 1/1 (25/3465) /content/video.mp4: 480x640 3 without_helmets, Done. (0.021s)
# video 1/1 (26/3465) /content/video.mp4: 480x640 3 without_helmets, Done. (0.022s)
# video 1/1 (27/3465) /content/video.mp4: 480x640 3 without_helmets, Done. (0.021s)
# video 1/1 (28/3465) /content/video.mp4: 480x640 2 without_helmets, Done. (0.022s)
# video 1/1 (29/3465) /content/video.mp4: 480x640 2 without_helmets, Done. (0.022s)
# video 1/1 (30/3465) /content/video.mp4: 480x640 2 without_helmets, Done. (0.021s)
# video 1/1 (31/3465) /content/video.mp4: 480x640 2 without_helmets, Done. (0.021s)
# video 1/1 (32/3465) /content/video.mp4: 480x640 2 without_helmets, Done. (0.021s)
# video 1/1 (33/3465) /content/video.mp4: 480x640 2 without_helmets, Done. (0.021s)
# video 1/1 (34/3465) /content/video.mp4: 480x640 2 without_helmets, Done. (0.021s)
# video 1/1 (35/3465) /content/video.mp4: 480x640 2 without_helmets, Done. (0.021s)
# video 1/1 (36/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.021s)
# video 1/1 (37/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.021s)
# video 1/1 (38/3465) /content/video.mp4: 480x640 1 helmet, 1 without_helmet, Done. (0.021s)
# video 1/1 (39/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.021s)
# video 1/1 (40/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.021s)
# video 1/1 (41/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (42/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (43/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (44/3465) /content/video.mp4: 480x640 1 helmet, Done. (0.020s)
# video 1/1 (45/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (46/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (47/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (48/3465) /content/video.mp4: 480x640 Done. (0.019s)
# video 1/1 (49/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.019s)
# video 1/1 (50/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (51/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (52/3465) /content/video.mp4: 480x640 Done. (0.019s)
# video 1/1 (53/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (54/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (55/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (56/3465) /content/video.mp4: 480x640 Done. (0.019s)
# video 1/1 (57/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (58/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (59/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (60/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (61/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (62/3465) /content/video.mp4: 480x640 1 without_helmet, 1 triples, Done. (0.019s)
# video 1/1 (63/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.019s)
# video 1/1 (64/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (65/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.019s)
# video 1/1 (66/3465) /content/video.mp4: 480x640 2 without_helmets, 1 triples, Done. (0.019s)
# video 1/1 (67/3465) /content/video.mp4: 480x640 2 without_helmets, 1 triples, Done. (0.019s)
# video 1/1 (68/3465) /content/video.mp4: 480x640 4 without_helmets, 1 triples, Done. (0.020s)
# video 1/1 (69/3465) /content/video.mp4: 480x640 3 without_helmets, 1 triples, Done. (0.019s)
# video 1/1 (70/3465) /content/video.mp4: 480x640 3 without_helmets, Done. (0.019s)
# video 1/1 (71/3465) /content/video.mp4: 480x640 2 without_helmets, Done. (0.020s)
# video 1/1 (72/3465) /content/video.mp4: 480x640 1 without_helmet, 1 triples, Done. (0.020s)
# video 1/1 (73/3465) /content/video.mp4: 480x640 2 without_helmets, Done. (0.020s)
# video 1/1 (74/3465) /content/video.mp4: 480x640 1 helmet, 3 without_helmets, Done. (0.020s)
# video 1/1 (75/3465) /content/video.mp4: 480x640 1 helmet, 2 without_helmets, Done. (0.019s)
# video 1/1 (76/3465) /content/video.mp4: 480x640 2 without_helmets, Done. (0.019s)
# video 1/1 (77/3465) /content/video.mp4: 480x640 2 without_helmets, Done. (0.020s)
# video 1/1 (78/3465) /content/video.mp4: 480x640 2 without_helmets, Done. (0.020s)
# video 1/1 (79/3465) /content/video.mp4: 480x640 2 without_helmets, Done. (0.020s)
# video 1/1 (80/3465) /content/video.mp4: 480x640 2 without_helmets, Done. (0.019s)
# video 1/1 (81/3465) /content/video.mp4: 480x640 2 without_helmets, Done. (0.020s)
# video 1/1 (82/3465) /content/video.mp4: 480x640 2 without_helmets, 1 triples, Done. (0.020s)
# video 1/1 (83/3465) /content/video.mp4: 480x640 2 without_helmets, Done. (0.020s)
# video 1/1 (84/3465) /content/video.mp4: 480x640 2 without_helmets, 1 triples, Done. (0.020s)
# video 1/1 (85/3465) /content/video.mp4: 480x640 2 without_helmets, 1 triples, Done. (0.020s)
# video 1/1 (86/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (87/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (88/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (89/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (90/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (91/3465) /content/video.mp4: 480x640 2 without_helmets, Done. (0.020s)
# video 1/1 (92/3465) /content/video.mp4: 480x640 2 without_helmets, Done. (0.020s)
# video 1/1 (93/3465) /content/video.mp4: 480x640 2 without_helmets, Done. (0.020s)
# video 1/1 (94/3465) /content/video.mp4: 480x640 2 without_helmets, Done. (0.020s)
# video 1/1 (95/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (96/3465) /content/video.mp4: 480x640 2 without_helmets, Done. (0.019s)
# video 1/1 (97/3465) /content/video.mp4: 480x640 2 without_helmets, Done. (0.020s)
# video 1/1 (98/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (99/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (100/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (101/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.019s)
# video 1/1 (102/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (103/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.019s)
# video 1/1 (104/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (105/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.019s)
# video 1/1 (106/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (107/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (108/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (109/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (110/3465) /content/video.mp4: 480x640 2 without_helmets, Done. (0.020s)
# video 1/1 (111/3465) /content/video.mp4: 480x640 2 without_helmets, Done. (0.020s)
# video 1/1 (112/3465) /content/video.mp4: 480x640 1 helmet, 2 without_helmets, Done. (0.020s)
# video 1/1 (113/3465) /content/video.mp4: 480x640 1 helmet, Done. (0.020s)
# video 1/1 (114/3465) /content/video.mp4: 480x640 1 helmet, 1 without_helmet, Done. (0.020s)
# video 1/1 (115/3465) /content/video.mp4: 480x640 1 helmet, Done. (0.020s)
# video 1/1 (116/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (117/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (118/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.019s)
# video 1/1 (119/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (120/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.019s)
# video 1/1 (121/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (122/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (123/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (124/3465) /content/video.mp4: 480x640 2 without_helmets, Done. (0.019s)
# video 1/1 (125/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.019s)
# video 1/1 (126/3465) /content/video.mp4: 480x640 2 without_helmets, Done. (0.020s)
# video 1/1 (127/3465) /content/video.mp4: 480x640 2 without_helmets, Done. (0.020s)
# video 1/1 (128/3465) /content/video.mp4: 480x640 2 without_helmets, Done. (0.020s)
# video 1/1 (129/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (130/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (131/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (132/3465) /content/video.mp4: 480x640 1 helmet, 1 without_helmet, Done. (0.019s)
# video 1/1 (133/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (134/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (135/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.019s)
# video 1/1 (136/3465) /content/video.mp4: 480x640 3 without_helmets, Done. (0.020s)
# video 1/1 (137/3465) /content/video.mp4: 480x640 Done. (0.019s)
# video 1/1 (138/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (139/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (140/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.019s)
# video 1/1 (141/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (142/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (143/3465) /content/video.mp4: 480x640 3 without_helmets, Done. (0.020s)
# video 1/1 (144/3465) /content/video.mp4: 480x640 2 without_helmets, Done. (0.020s)
# video 1/1 (145/3465) /content/video.mp4: 480x640 2 without_helmets, Done. (0.020s)
# video 1/1 (146/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (147/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (148/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (149/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (150/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (151/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (152/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.019s)
# video 1/1 (153/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (154/3465) /content/video.mp4: 480x640 2 without_helmets, 1 triples, Done. (0.020s)
# video 1/1 (155/3465) /content/video.mp4: 480x640 2 without_helmets, 1 triples, Done. (0.020s)
# video 1/1 (156/3465) /content/video.mp4: 480x640 2 without_helmets, Done. (0.020s)
# video 1/1 (157/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.019s)
# video 1/1 (158/3465) /content/video.mp4: 480x640 2 without_helmets, 1 triples, Done. (0.020s)
# video 1/1 (159/3465) /content/video.mp4: 480x640 2 without_helmets, Done. (0.020s)
# video 1/1 (160/3465) /content/video.mp4: 480x640 2 without_helmets, Done. (0.020s)
# video 1/1 (161/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (162/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (163/3465) /content/video.mp4: 480x640 2 without_helmets, Done. (0.020s)
# video 1/1 (164/3465) /content/video.mp4: 480x640 2 without_helmets, Done. (0.020s)
# video 1/1 (165/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (166/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (167/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (168/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (169/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (170/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.019s)
# video 1/1 (171/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (172/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (173/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (174/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (175/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.019s)
# video 1/1 (176/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (177/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.019s)
# video 1/1 (178/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (179/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (180/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (181/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (182/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (183/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (184/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (185/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (186/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (187/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (188/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (189/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (190/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (191/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (192/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (193/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (194/3465) /content/video.mp4: 480x640 3 without_helmets, Done. (0.020s)
# video 1/1 (195/3465) /content/video.mp4: 480x640 3 without_helmets, Done. (0.019s)
# video 1/1 (196/3465) /content/video.mp4: 480x640 3 without_helmets, Done. (0.020s)
# video 1/1 (197/3465) /content/video.mp4: 480x640 3 without_helmets, Done. (0.020s)
# video 1/1 (198/3465) /content/video.mp4: 480x640 3 without_helmets, Done. (0.020s)
# video 1/1 (199/3465) /content/video.mp4: 480x640 3 without_helmets, Done. (0.020s)
# video 1/1 (200/3465) /content/video.mp4: 480x640 5 without_helmets, Done. (0.019s)
# video 1/1 (201/3465) /content/video.mp4: 480x640 2 without_helmets, Done. (0.020s)
# video 1/1 (202/3465) /content/video.mp4: 480x640 4 without_helmets, Done. (0.019s)
# video 1/1 (203/3465) /content/video.mp4: 480x640 4 without_helmets, Done. (0.020s)
# video 1/1 (204/3465) /content/video.mp4: 480x640 4 without_helmets, Done. (0.020s)
# video 1/1 (205/3465) /content/video.mp4: 480x640 3 without_helmets, Done. (0.020s)
# video 1/1 (206/3465) /content/video.mp4: 480x640 3 without_helmets, Done. (0.020s)
# video 1/1 (207/3465) /content/video.mp4: 480x640 4 without_helmets, Done. (0.020s)
# video 1/1 (208/3465) /content/video.mp4: 480x640 5 without_helmets, Done. (0.020s)
# video 1/1 (209/3465) /content/video.mp4: 480x640 3 without_helmets, Done. (0.020s)
# video 1/1 (210/3465) /content/video.mp4: 480x640 2 without_helmets, Done. (0.020s)
# video 1/1 (211/3465) /content/video.mp4: 480x640 3 without_helmets, Done. (0.020s)
# video 1/1 (212/3465) /content/video.mp4: 480x640 3 without_helmets, Done. (0.020s)
# video 1/1 (213/3465) /content/video.mp4: 480x640 3 without_helmets, Done. (0.018s)
# video 1/1 (214/3465) /content/video.mp4: 480x640 3 without_helmets, Done. (0.020s)
# video 1/1 (215/3465) /content/video.mp4: 480x640 2 without_helmets, Done. (0.020s)
# video 1/1 (216/3465) /content/video.mp4: 480x640 5 without_helmets, Done. (0.020s)
# video 1/1 (217/3465) /content/video.mp4: 480x640 3 without_helmets, Done. (0.020s)
# video 1/1 (218/3465) /content/video.mp4: 480x640 3 without_helmets, Done. (0.020s)
# video 1/1 (219/3465) /content/video.mp4: 480x640 3 without_helmets, Done. (0.020s)
# video 1/1 (220/3465) /content/video.mp4: 480x640 3 without_helmets, Done. (0.020s)
# video 1/1 (221/3465) /content/video.mp4: 480x640 2 without_helmets, Done. (0.020s)
# video 1/1 (222/3465) /content/video.mp4: 480x640 2 without_helmets, Done. (0.020s)
# video 1/1 (223/3465) /content/video.mp4: 480x640 3 without_helmets, Done. (0.020s)
# video 1/1 (224/3465) /content/video.mp4: 480x640 3 without_helmets, Done. (0.019s)
# video 1/1 (225/3465) /content/video.mp4: 480x640 4 without_helmets, Done. (0.019s)
# video 1/1 (226/3465) /content/video.mp4: 480x640 4 without_helmets, Done. (0.020s)
# video 1/1 (227/3465) /content/video.mp4: 480x640 4 without_helmets, Done. (0.020s)
# video 1/1 (228/3465) /content/video.mp4: 480x640 4 without_helmets, Done. (0.020s)
# video 1/1 (229/3465) /content/video.mp4: 480x640 5 without_helmets, Done. (0.020s)
# video 1/1 (230/3465) /content/video.mp4: 480x640 5 without_helmets, Done. (0.020s)
# video 1/1 (231/3465) /content/video.mp4: 480x640 5 without_helmets, Done. (0.020s)
# video 1/1 (232/3465) /content/video.mp4: 480x640 5 without_helmets, Done. (0.020s)
# video 1/1 (233/3465) /content/video.mp4: 480x640 5 without_helmets, Done. (0.019s)
# video 1/1 (234/3465) /content/video.mp4: 480x640 5 without_helmets, Done. (0.020s)
# video 1/1 (235/3465) /content/video.mp4: 480x640 6 without_helmets, Done. (0.019s)
# video 1/1 (236/3465) /content/video.mp4: 480x640 5 without_helmets, Done. (0.020s)
# video 1/1 (237/3465) /content/video.mp4: 480x640 1 helmet, 5 without_helmets, Done. (0.020s)
# video 1/1 (238/3465) /content/video.mp4: 480x640 1 helmet, 6 without_helmets, Done. (0.020s)
# video 1/1 (239/3465) /content/video.mp4: 480x640 5 without_helmets, Done. (0.020s)
# video 1/1 (240/3465) /content/video.mp4: 480x640 3 without_helmets, Done. (0.020s)
# video 1/1 (241/3465) /content/video.mp4: 480x640 1 helmet, 3 without_helmets, Done. (0.019s)
# video 1/1 (242/3465) /content/video.mp4: 480x640 1 helmet, 2 without_helmets, Done. (0.019s)
# video 1/1 (243/3465) /content/video.mp4: 480x640 3 without_helmets, Done. (0.019s)
# video 1/1 (244/3465) /content/video.mp4: 480x640 1 helmet, 2 without_helmets, Done. (0.019s)
# video 1/1 (245/3465) /content/video.mp4: 480x640 3 without_helmets, Done. (0.019s)
# video 1/1 (246/3465) /content/video.mp4: 480x640 4 without_helmets, Done. (0.020s)
# video 1/1 (247/3465) /content/video.mp4: 480x640 3 without_helmets, Done. (0.020s)
# video 1/1 (248/3465) /content/video.mp4: 480x640 4 without_helmets, Done. (0.020s)
# video 1/1 (249/3465) /content/video.mp4: 480x640 4 without_helmets, Done. (0.020s)
# video 1/1 (250/3465) /content/video.mp4: 480x640 6 without_helmets, Done. (0.020s)
# video 1/1 (251/3465) /content/video.mp4: 480x640 3 without_helmets, Done. (0.020s)
# video 1/1 (252/3465) /content/video.mp4: 480x640 5 without_helmets, Done. (0.020s)
# video 1/1 (253/3465) /content/video.mp4: 480x640 6 without_helmets, Done. (0.020s)
# video 1/1 (254/3465) /content/video.mp4: 480x640 5 without_helmets, Done. (0.020s)
# video 1/1 (255/3465) /content/video.mp4: 480x640 3 without_helmets, Done. (0.020s)
# video 1/1 (256/3465) /content/video.mp4: 480x640 2 without_helmets, Done. (0.020s)
# video 1/1 (257/3465) /content/video.mp4: 480x640 4 without_helmets, Done. (0.020s)
# video 1/1 (258/3465) /content/video.mp4: 480x640 4 without_helmets, Done. (0.020s)
# video 1/1 (259/3465) /content/video.mp4: 480x640 4 without_helmets, Done. (0.020s)
# video 1/1 (260/3465) /content/video.mp4: 480x640 5 without_helmets, Done. (0.020s)
# video 1/1 (261/3465) /content/video.mp4: 480x640 4 without_helmets, Done. (0.020s)
# video 1/1 (262/3465) /content/video.mp4: 480x640 4 without_helmets, Done. (0.020s)
# video 1/1 (263/3465) /content/video.mp4: 480x640 6 without_helmets, Done. (0.020s)
# video 1/1 (264/3465) /content/video.mp4: 480x640 4 without_helmets, Done. (0.020s)
# video 1/1 (265/3465) /content/video.mp4: 480x640 5 without_helmets, Done. (0.020s)
# video 1/1 (266/3465) /content/video.mp4: 480x640 5 without_helmets, 1 triples, Done. (0.020s)
# video 1/1 (267/3465) /content/video.mp4: 480x640 4 without_helmets, 1 triples, Done. (0.020s)
# video 1/1 (268/3465) /content/video.mp4: 480x640 4 without_helmets, 1 triples, Done. (0.020s)
# video 1/1 (269/3465) /content/video.mp4: 480x640 5 without_helmets, 1 triples, Done. (0.020s)
# video 1/1 (270/3465) /content/video.mp4: 480x640 6 without_helmets, 2 tripless, Done. (0.020s)
# video 1/1 (271/3465) /content/video.mp4: 480x640 4 without_helmets, 1 triples, Done. (0.020s)
# video 1/1 (272/3465) /content/video.mp4: 480x640 4 without_helmets, Done. (0.020s)
# video 1/1 (273/3465) /content/video.mp4: 480x640 4 without_helmets, 1 triples, Done. (0.020s)
# video 1/1 (274/3465) /content/video.mp4: 480x640 4 without_helmets, Done. (0.020s)
# video 1/1 (275/3465) /content/video.mp4: 480x640 4 without_helmets, 1 triples, Done. (0.020s)
# video 1/1 (276/3465) /content/video.mp4: 480x640 5 without_helmets, Done. (0.019s)
# video 1/1 (277/3465) /content/video.mp4: 480x640 4 without_helmets, Done. (0.019s)
# video 1/1 (278/3465) /content/video.mp4: 480x640 3 without_helmets, Done. (0.020s)
# video 1/1 (279/3465) /content/video.mp4: 480x640 3 without_helmets, Done. (0.020s)
# video 1/1 (280/3465) /content/video.mp4: 480x640 4 without_helmets, Done. (0.019s)
# video 1/1 (281/3465) /content/video.mp4: 480x640 4 without_helmets, Done. (0.020s)
# video 1/1 (282/3465) /content/video.mp4: 480x640 3 without_helmets, Done. (0.019s)
# video 1/1 (283/3465) /content/video.mp4: 480x640 3 without_helmets, Done. (0.020s)
# video 1/1 (284/3465) /content/video.mp4: 480x640 3 without_helmets, Done. (0.020s)
# video 1/1 (285/3465) /content/video.mp4: 480x640 3 without_helmets, Done. (0.020s)
# video 1/1 (286/3465) /content/video.mp4: 480x640 4 without_helmets, Done. (0.020s)
# video 1/1 (287/3465) /content/video.mp4: 480x640 3 without_helmets, Done. (0.020s)
# video 1/1 (288/3465) /content/video.mp4: 480x640 2 without_helmets, Done. (0.020s)
# video 1/1 (289/3465) /content/video.mp4: 480x640 2 without_helmets, Done. (0.020s)
# video 1/1 (290/3465) /content/video.mp4: 480x640 2 without_helmets, Done. (0.019s)
# video 1/1 (291/3465) /content/video.mp4: 480x640 2 without_helmets, Done. (0.020s)
# video 1/1 (292/3465) /content/video.mp4: 480x640 2 without_helmets, Done. (0.020s)
# video 1/1 (293/3465) /content/video.mp4: 480x640 2 without_helmets, Done. (0.020s)
# video 1/1 (294/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (295/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (296/3465) /content/video.mp4: 480x640 4 without_helmets, Done. (0.020s)
# video 1/1 (297/3465) /content/video.mp4: 480x640 4 without_helmets, Done. (0.020s)
# video 1/1 (298/3465) /content/video.mp4: 480x640 4 without_helmets, Done. (0.020s)
# video 1/1 (299/3465) /content/video.mp4: 480x640 5 without_helmets, Done. (0.019s)
# video 1/1 (300/3465) /content/video.mp4: 480x640 5 without_helmets, Done. (0.020s)
# video 1/1 (301/3465) /content/video.mp4: 480x640 6 without_helmets, Done. (0.020s)
# video 1/1 (302/3465) /content/video.mp4: 480x640 5 without_helmets, Done. (0.020s)
# video 1/1 (303/3465) /content/video.mp4: 480x640 7 without_helmets, Done. (0.020s)
# video 1/1 (304/3465) /content/video.mp4: 480x640 6 without_helmets, Done. (0.020s)
# video 1/1 (305/3465) /content/video.mp4: 480x640 6 without_helmets, Done. (0.020s)
# video 1/1 (306/3465) /content/video.mp4: 480x640 5 without_helmets, Done. (0.020s)
# video 1/1 (307/3465) /content/video.mp4: 480x640 5 without_helmets, Done. (0.020s)
# video 1/1 (308/3465) /content/video.mp4: 480x640 4 without_helmets, Done. (0.020s)
# video 1/1 (309/3465) /content/video.mp4: 480x640 4 without_helmets, Done. (0.020s)
# video 1/1 (310/3465) /content/video.mp4: 480x640 4 without_helmets, Done. (0.020s)
# video 1/1 (311/3465) /content/video.mp4: 480x640 3 without_helmets, Done. (0.020s)
# video 1/1 (312/3465) /content/video.mp4: 480x640 3 without_helmets, Done. (0.020s)
# video 1/1 (313/3465) /content/video.mp4: 480x640 2 without_helmets, Done. (0.019s)
# video 1/1 (314/3465) /content/video.mp4: 480x640 2 without_helmets, Done. (0.020s)
# video 1/1 (315/3465) /content/video.mp4: 480x640 3 without_helmets, Done. (0.020s)
# video 1/1 (316/3465) /content/video.mp4: 480x640 4 without_helmets, Done. (0.019s)
# video 1/1 (317/3465) /content/video.mp4: 480x640 4 without_helmets, Done. (0.020s)
# video 1/1 (318/3465) /content/video.mp4: 480x640 4 without_helmets, Done. (0.019s)
# video 1/1 (319/3465) /content/video.mp4: 480x640 3 without_helmets, Done. (0.020s)
# video 1/1 (320/3465) /content/video.mp4: 480x640 3 without_helmets, Done. (0.020s)
# video 1/1 (321/3465) /content/video.mp4: 480x640 4 without_helmets, Done. (0.020s)
# video 1/1 (322/3465) /content/video.mp4: 480x640 3 without_helmets, Done. (0.020s)
# video 1/1 (323/3465) /content/video.mp4: 480x640 3 without_helmets, Done. (0.019s)
# video 1/1 (324/3465) /content/video.mp4: 480x640 2 without_helmets, Done. (0.020s)
# video 1/1 (325/3465) /content/video.mp4: 480x640 2 without_helmets, Done. (0.020s)
# video 1/1 (326/3465) /content/video.mp4: 480x640 2 without_helmets, Done. (0.020s)
# video 1/1 (327/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (328/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (329/3465) /content/video.mp4: 480x640 2 without_helmets, Done. (0.019s)
# video 1/1 (330/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (331/3465) /content/video.mp4: 480x640 2 without_helmets, Done. (0.020s)
# video 1/1 (332/3465) /content/video.mp4: 480x640 1 helmet, 2 without_helmets, Done. (0.020s)
# video 1/1 (333/3465) /content/video.mp4: 480x640 2 without_helmets, Done. (0.019s)
# video 1/1 (334/3465) /content/video.mp4: 480x640 2 without_helmets, Done. (0.020s)
# video 1/1 (335/3465) /content/video.mp4: 480x640 2 without_helmets, Done. (0.020s)
# video 1/1 (336/3465) /content/video.mp4: 480x640 2 without_helmets, Done. (0.020s)
# video 1/1 (337/3465) /content/video.mp4: 480x640 2 without_helmets, Done. (0.020s)
# video 1/1 (338/3465) /content/video.mp4: 480x640 2 without_helmets, Done. (0.020s)
# video 1/1 (339/3465) /content/video.mp4: 480x640 1 helmet, 2 without_helmets, Done. (0.019s)
# video 1/1 (340/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (341/3465) /content/video.mp4: 480x640 2 without_helmets, Done. (0.020s)
# video 1/1 (342/3465) /content/video.mp4: 480x640 2 without_helmets, Done. (0.020s)
# video 1/1 (343/3465) /content/video.mp4: 480x640 1 helmet, 1 triples, Done. (0.021s)
# video 1/1 (344/3465) /content/video.mp4: 480x640 1 helmet, Done. (0.020s)
# video 1/1 (345/3465) /content/video.mp4: 480x640 1 helmet, 1 without_helmet, Done. (0.020s)
# video 1/1 (346/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (347/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (348/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (349/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (350/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (351/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.019s)
# video 1/1 (352/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (353/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (354/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (355/3465) /content/video.mp4: 480x640 1 without_helmet, 1 triples, Done. (0.020s)
# video 1/1 (356/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (357/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (358/3465) /content/video.mp4: 480x640 2 without_helmets, Done. (0.020s)
# video 1/1 (359/3465) /content/video.mp4: 480x640 2 without_helmets, Done. (0.020s)
# video 1/1 (360/3465) /content/video.mp4: 480x640 2 without_helmets, Done. (0.019s)
# video 1/1 (361/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (362/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (363/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.019s)
# video 1/1 (364/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (365/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (366/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (367/3465) /content/video.mp4: 480x640 1 helmet, 1 without_helmet, Done. (0.020s)
# video 1/1 (368/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (369/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (370/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.019s)
# video 1/1 (371/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (372/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (373/3465) /content/video.mp4: 480x640 1 helmet, Done. (0.020s)
# video 1/1 (374/3465) /content/video.mp4: 480x640 1 helmet, 1 without_helmet, Done. (0.019s)
# video 1/1 (375/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (376/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (377/3465) /content/video.mp4: 480x640 1 helmet, 1 without_helmet, Done. (0.020s)
# video 1/1 (378/3465) /content/video.mp4: 480x640 1 helmet, 1 without_helmet, Done. (0.020s)
# video 1/1 (379/3465) /content/video.mp4: 480x640 1 helmet, 1 without_helmet, Done. (0.020s)
# video 1/1 (380/3465) /content/video.mp4: 480x640 1 helmet, Done. (0.020s)
# video 1/1 (381/3465) /content/video.mp4: 480x640 1 helmet, Done. (0.020s)
# video 1/1 (382/3465) /content/video.mp4: 480x640 1 helmet, Done. (0.019s)
# video 1/1 (383/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (384/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (385/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (386/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (387/3465) /content/video.mp4: 480x640 1 triples, Done. (0.020s)
# video 1/1 (388/3465) /content/video.mp4: 480x640 1 triples, Done. (0.020s)
# video 1/1 (389/3465) /content/video.mp4: 480x640 1 triples, Done. (0.020s)
# video 1/1 (390/3465) /content/video.mp4: 480x640 1 without_helmet, 1 triples, Done. (0.020s)
# video 1/1 (391/3465) /content/video.mp4: 480x640 1 triples, Done. (0.020s)
# video 1/1 (392/3465) /content/video.mp4: 480x640 3 without_helmets, Done. (0.020s)
# video 1/1 (393/3465) /content/video.mp4: 480x640 1 helmet, Done. (0.020s)
# video 1/1 (394/3465) /content/video.mp4: 480x640 2 without_helmets, 1 triples, Done. (0.020s)
# video 1/1 (395/3465) /content/video.mp4: 480x640 1 helmet, 2 without_helmets, 1 triples, Done. (0.019s)
# video 1/1 (396/3465) /content/video.mp4: 480x640 1 without_helmet, 1 triples, Done. (0.020s)
# video 1/1 (397/3465) /content/video.mp4: 480x640 2 without_helmets, Done. (0.020s)
# video 1/1 (398/3465) /content/video.mp4: 480x640 3 without_helmets, Done. (0.020s)
# video 1/1 (399/3465) /content/video.mp4: 480x640 3 without_helmets, Done. (0.020s)
# video 1/1 (400/3465) /content/video.mp4: 480x640 3 without_helmets, Done. (0.020s)
# video 1/1 (401/3465) /content/video.mp4: 480x640 3 without_helmets, Done. (0.020s)
# video 1/1 (402/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (403/3465) /content/video.mp4: 480x640 2 without_helmets, Done. (0.020s)
# video 1/1 (404/3465) /content/video.mp4: 480x640 2 without_helmets, Done. (0.020s)
# video 1/1 (405/3465) /content/video.mp4: 480x640 2 without_helmets, Done. (0.020s)
# video 1/1 (406/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (407/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (408/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.019s)
# video 1/1 (409/3465) /content/video.mp4: 480x640 2 without_helmets, Done. (0.020s)
# video 1/1 (410/3465) /content/video.mp4: 480x640 2 without_helmets, 1 triples, Done. (0.020s)
# video 1/1 (411/3465) /content/video.mp4: 480x640 2 without_helmets, 1 triples, Done. (0.020s)
# video 1/1 (412/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (413/3465) /content/video.mp4: 480x640 2 without_helmets, Done. (0.020s)
# video 1/1 (414/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (415/3465) /content/video.mp4: 480x640 1 helmet, 1 without_helmet, Done. (0.020s)
# video 1/1 (416/3465) /content/video.mp4: 480x640 1 helmet, Done. (0.020s)
# video 1/1 (417/3465) /content/video.mp4: 480x640 1 triples, Done. (0.020s)
# video 1/1 (418/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (419/3465) /content/video.mp4: 480x640 1 triples, Done. (0.020s)
# video 1/1 (420/3465) /content/video.mp4: 480x640 1 without_helmet, 1 triples, Done. (0.019s)
# video 1/1 (421/3465) /content/video.mp4: 480x640 2 helmets, 1 triples, Done. (0.019s)
# video 1/1 (422/3465) /content/video.mp4: 480x640 2 helmets, 1 triples, Done. (0.020s)
# video 1/1 (423/3465) /content/video.mp4: 480x640 1 helmet, 1 triples, Done. (0.020s)
# video 1/1 (424/3465) /content/video.mp4: 480x640 1 helmet, 1 without_helmet, Done. (0.020s)
# video 1/1 (425/3465) /content/video.mp4: 480x640 1 helmet, Done. (0.020s)
# video 1/1 (426/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (427/3465) /content/video.mp4: 480x640 1 helmet, Done. (0.020s)
# video 1/1 (428/3465) /content/video.mp4: 480x640 4 helmets, Done. (0.020s)
# video 1/1 (429/3465) /content/video.mp4: 480x640 2 helmets, 1 triples, Done. (0.019s)
# video 1/1 (430/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (431/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (432/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (433/3465) /content/video.mp4: 480x640 Done. (0.019s)
# video 1/1 (434/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (435/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (436/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (437/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (438/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (439/3465) /content/video.mp4: 480x640 2 without_helmets, 1 triples, Done. (0.020s)
# video 1/1 (440/3465) /content/video.mp4: 480x640 2 without_helmets, Done. (0.019s)
# video 1/1 (441/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (442/3465) /content/video.mp4: 480x640 1 helmet, 1 without_helmet, Done. (0.020s)
# video 1/1 (443/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (444/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (445/3465) /content/video.mp4: 480x640 1 helmet, 2 without_helmets, 1 triples, Done. (0.020s)
# video 1/1 (446/3465) /content/video.mp4: 480x640 1 helmet, Done. (0.019s)
# video 1/1 (447/3465) /content/video.mp4: 480x640 1 helmet, 1 without_helmet, Done. (0.020s)
# video 1/1 (448/3465) /content/video.mp4: 480x640 1 helmet, 2 without_helmets, Done. (0.020s)
# video 1/1 (449/3465) /content/video.mp4: 480x640 1 helmet, 3 without_helmets, Done. (0.020s)
# video 1/1 (450/3465) /content/video.mp4: 480x640 1 helmet, 2 without_helmets, Done. (0.020s)
# video 1/1 (451/3465) /content/video.mp4: 480x640 3 without_helmets, Done. (0.020s)
# video 1/1 (452/3465) /content/video.mp4: 480x640 3 without_helmets, Done. (0.019s)
# video 1/1 (453/3465) /content/video.mp4: 480x640 3 without_helmets, Done. (0.020s)
# video 1/1 (454/3465) /content/video.mp4: 480x640 3 without_helmets, Done. (0.020s)
# video 1/1 (455/3465) /content/video.mp4: 480x640 3 without_helmets, Done. (0.020s)
# video 1/1 (456/3465) /content/video.mp4: 480x640 3 without_helmets, Done. (0.020s)
# video 1/1 (457/3465) /content/video.mp4: 480x640 2 helmets, 4 without_helmets, Done. (0.020s)
# video 1/1 (458/3465) /content/video.mp4: 480x640 1 helmet, 3 without_helmets, Done. (0.020s)
# video 1/1 (459/3465) /content/video.mp4: 480x640 1 helmet, 2 without_helmets, Done. (0.020s)
# video 1/1 (460/3465) /content/video.mp4: 480x640 1 helmet, 2 without_helmets, Done. (0.020s)
# video 1/1 (461/3465) /content/video.mp4: 480x640 1 helmet, 2 without_helmets, Done. (0.020s)
# video 1/1 (462/3465) /content/video.mp4: 480x640 1 helmet, 2 without_helmets, Done. (0.019s)
# video 1/1 (463/3465) /content/video.mp4: 480x640 1 helmet, 4 without_helmets, Done. (0.020s)
# video 1/1 (464/3465) /content/video.mp4: 480x640 1 helmet, 3 without_helmets, Done. (0.019s)
# video 1/1 (465/3465) /content/video.mp4: 480x640 1 helmet, 6 without_helmets, Done. (0.019s)
# video 1/1 (466/3465) /content/video.mp4: 480x640 1 helmet, 3 without_helmets, Done. (0.020s)
# video 1/1 (467/3465) /content/video.mp4: 480x640 1 helmet, 5 without_helmets, Done. (0.020s)
# video 1/1 (468/3465) /content/video.mp4: 480x640 1 helmet, 7 without_helmets, Done. (0.019s)
# video 1/1 (469/3465) /content/video.mp4: 480x640 1 helmet, 5 without_helmets, Done. (0.020s)
# video 1/1 (470/3465) /content/video.mp4: 480x640 1 helmet, 3 without_helmets, Done. (0.020s)
# video 1/1 (471/3465) /content/video.mp4: 480x640 1 helmet, 3 without_helmets, Done. (0.020s)
# video 1/1 (472/3465) /content/video.mp4: 480x640 1 helmet, 3 without_helmets, Done. (0.020s)
# video 1/1 (473/3465) /content/video.mp4: 480x640 1 helmet, 3 without_helmets, 1 triples, Done. (0.020s)
# video 1/1 (474/3465) /content/video.mp4: 480x640 1 helmet, 2 without_helmets, Done. (0.020s)
# video 1/1 (475/3465) /content/video.mp4: 480x640 2 without_helmets, Done. (0.020s)
# video 1/1 (476/3465) /content/video.mp4: 480x640 1 helmet, 2 without_helmets, 1 triples, Done. (0.019s)
# video 1/1 (477/3465) /content/video.mp4: 480x640 1 helmet, 2 without_helmets, 1 triples, Done. (0.020s)
# video 1/1 (478/3465) /content/video.mp4: 480x640 1 helmet, 2 without_helmets, Done. (0.020s)
# video 1/1 (479/3465) /content/video.mp4: 480x640 1 helmet, 4 without_helmets, 1 triples, Done. (0.020s)
# video 1/1 (480/3465) /content/video.mp4: 480x640 1 helmet, 4 without_helmets, 1 triples, Done. (0.020s)
# video 1/1 (481/3465) /content/video.mp4: 480x640 1 helmet, 4 without_helmets, 1 triples, Done. (0.020s)
# video 1/1 (482/3465) /content/video.mp4: 480x640 1 helmet, 4 without_helmets, 1 triples, Done. (0.019s)
# video 1/1 (483/3465) /content/video.mp4: 480x640 4 without_helmets, Done. (0.019s)
# video 1/1 (484/3465) /content/video.mp4: 480x640 3 without_helmets, 1 triples, Done. (0.020s)
# video 1/1 (485/3465) /content/video.mp4: 480x640 2 without_helmets, Done. (0.019s)
# video 1/1 (486/3465) /content/video.mp4: 480x640 1 helmet, 2 without_helmets, 1 triples, Done. (0.020s)
# video 1/1 (487/3465) /content/video.mp4: 480x640 1 helmet, 2 without_helmets, Done. (0.020s)
# video 1/1 (488/3465) /content/video.mp4: 480x640 1 helmet, 2 without_helmets, 1 triples, Done. (0.020s)
# video 1/1 (489/3465) /content/video.mp4: 480x640 1 helmet, 2 without_helmets, 1 triples, Done. (0.020s)
# video 1/1 (490/3465) /content/video.mp4: 480x640 1 helmet, 3 without_helmets, Done. (0.020s)
# video 1/1 (491/3465) /content/video.mp4: 480x640 1 helmet, 1 without_helmet, Done. (0.020s)
# video 1/1 (492/3465) /content/video.mp4: 480x640 1 helmet, 2 without_helmets, Done. (0.020s)
# video 1/1 (493/3465) /content/video.mp4: 480x640 1 helmet, 3 without_helmets, Done. (0.020s)
# video 1/1 (494/3465) /content/video.mp4: 480x640 1 helmet, 3 without_helmets, Done. (0.020s)
# video 1/1 (495/3465) /content/video.mp4: 480x640 1 helmet, 4 without_helmets, 1 triples, Done. (0.020s)
# video 1/1 (496/3465) /content/video.mp4: 480x640 1 helmet, 1 without_helmet, Done. (0.019s)
# video 1/1 (497/3465) /content/video.mp4: 480x640 1 helmet, 3 without_helmets, Done. (0.019s)
# video 1/1 (498/3465) /content/video.mp4: 480x640 1 helmet, 2 without_helmets, Done. (0.020s)
# video 1/1 (499/3465) /content/video.mp4: 480x640 1 helmet, 1 without_helmet, Done. (0.019s)
# video 1/1 (500/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (501/3465) /content/video.mp4: 480x640 1 helmet, Done. (0.020s)
# video 1/1 (502/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (503/3465) /content/video.mp4: 480x640 2 without_helmets, Done. (0.020s)
# video 1/1 (504/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (505/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.019s)
# video 1/1 (506/3465) /content/video.mp4: 480x640 Done. (0.019s)
# video 1/1 (507/3465) /content/video.mp4: 480x640 1 helmet, Done. (0.020s)
# video 1/1 (508/3465) /content/video.mp4: 480x640 1 helmet, 1 without_helmet, Done. (0.020s)
# video 1/1 (509/3465) /content/video.mp4: 480x640 1 helmet, 1 without_helmet, Done. (0.019s)
# video 1/1 (510/3465) /content/video.mp4: 480x640 1 helmet, 1 without_helmet, Done. (0.020s)
# video 1/1 (511/3465) /content/video.mp4: 480x640 1 helmet, 1 without_helmet, Done. (0.020s)
# video 1/1 (512/3465) /content/video.mp4: 480x640 1 helmet, 1 without_helmet, Done. (0.020s)
# video 1/1 (513/3465) /content/video.mp4: 480x640 1 helmet, 1 without_helmet, Done. (0.020s)
# video 1/1 (514/3465) /content/video.mp4: 480x640 1 helmet, 2 without_helmets, Done. (0.020s)
# video 1/1 (515/3465) /content/video.mp4: 480x640 3 without_helmets, Done. (0.020s)
# video 1/1 (516/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (517/3465) /content/video.mp4: 480x640 2 without_helmets, Done. (0.019s)
# video 1/1 (518/3465) /content/video.mp4: 480x640 1 helmet, 1 without_helmet, Done. (0.020s)
# video 1/1 (519/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.019s)
# video 1/1 (520/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.019s)
# video 1/1 (521/3465) /content/video.mp4: 480x640 2 without_helmets, Done. (0.020s)
# video 1/1 (522/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (523/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (524/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (525/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (526/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (527/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (528/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (529/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (530/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (531/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (532/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (533/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (534/3465) /content/video.mp4: 480x640 1 triples, Done. (0.020s)
# video 1/1 (535/3465) /content/video.mp4: 480x640 Done. (0.019s)
# video 1/1 (536/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (537/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (538/3465) /content/video.mp4: 480x640 1 helmet, Done. (0.019s)
# video 1/1 (539/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (540/3465) /content/video.mp4: 480x640 2 without_helmets, Done. (0.020s)
# video 1/1 (541/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (542/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (543/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (544/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (545/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (546/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (547/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (548/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (549/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (550/3465) /content/video.mp4: 480x640 Done. (0.019s)
# video 1/1 (551/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (552/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (553/3465) /content/video.mp4: 480x640 Done. (0.019s)
# video 1/1 (554/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (555/3465) /content/video.mp4: 480x640 1 helmet, Done. (0.020s)
# video 1/1 (556/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (557/3465) /content/video.mp4: 480x640 1 helmet, Done. (0.020s)
# video 1/1 (558/3465) /content/video.mp4: 480x640 1 helmet, Done. (0.020s)
# video 1/1 (559/3465) /content/video.mp4: 480x640 1 helmet, Done. (0.020s)
# video 1/1 (560/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (561/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (562/3465) /content/video.mp4: 480x640 Done. (0.019s)
# video 1/1 (563/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (564/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (565/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (566/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (567/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (568/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (569/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (570/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (571/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (572/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (573/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (574/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (575/3465) /content/video.mp4: 480x640 Done. (0.019s)
# video 1/1 (576/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (577/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (578/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (579/3465) /content/video.mp4: 480x640 Done. (0.020s)
# ...
# video 1/1 (3234/3465) /content/video.mp4: 480x640 3 helmets, 1 without_helmet, Done. (0.020s)
# video 1/1 (3235/3465) /content/video.mp4: 480x640 5 helmets, 2 without_helmets, Done. (0.020s)
# video 1/1 (3236/3465) /content/video.mp4: 480x640 3 helmets, 1 without_helmet, Done. (0.020s)
# video 1/1 (3237/3465) /content/video.mp4: 480x640 4 helmets, 3 without_helmets, Done. (0.020s)
# video 1/1 (3238/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3239/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3240/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3241/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3242/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3243/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3244/3465) /content/video.mp4: 480x640 Done. (0.019s)
# video 1/1 (3245/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3246/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3247/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3248/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3249/3465) /content/video.mp4: 480x640 Done. (0.019s)
# video 1/1 (3250/3465) /content/video.mp4: 480x640 Done. (0.019s)
# video 1/1 (3251/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3252/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3253/3465) /content/video.mp4: 480x640 Done. (0.019s)
# video 1/1 (3254/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3255/3465) /content/video.mp4: 480x640 Done. (0.019s)
# video 1/1 (3256/3465) /content/video.mp4: 480x640 Done. (0.019s)
# video 1/1 (3257/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3258/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3259/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3260/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3261/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3262/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3263/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3264/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3265/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3266/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3267/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3268/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3269/3465) /content/video.mp4: 480x640 Done. (0.019s)
# video 1/1 (3270/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3271/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3272/3465) /content/video.mp4: 480x640 Done. (0.019s)
# video 1/1 (3273/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3274/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3275/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3276/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3277/3465) /content/video.mp4: 480x640 1 helmet, Done. (0.020s)
# video 1/1 (3278/3465) /content/video.mp4: 480x640 Done. (0.019s)
# video 1/1 (3279/3465) /content/video.mp4: 480x640 2 helmets, Done. (0.020s)
# video 1/1 (3280/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3281/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3282/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3283/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3284/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3285/3465) /content/video.mp4: 480x640 1 helmet, Done. (0.020s)
# video 1/1 (3286/3465) /content/video.mp4: 480x640 2 helmets, Done. (0.020s)
# video 1/1 (3287/3465) /content/video.mp4: 480x640 1 helmet, Done. (0.020s)
# video 1/1 (3288/3465) /content/video.mp4: 480x640 1 helmet, Done. (0.020s)
# video 1/1 (3289/3465) /content/video.mp4: 480x640 2 helmets, Done. (0.020s)
# video 1/1 (3290/3465) /content/video.mp4: 480x640 2 helmets, Done. (0.020s)
# video 1/1 (3291/3465) /content/video.mp4: 480x640 1 helmet, Done. (0.019s)
# video 1/1 (3292/3465) /content/video.mp4: 480x640 Done. (0.019s)
# video 1/1 (3293/3465) /content/video.mp4: 480x640 1 helmet, Done. (0.020s)
# video 1/1 (3294/3465) /content/video.mp4: 480x640 Done. (0.019s)
# video 1/1 (3295/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3296/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3297/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (3298/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (3299/3465) /content/video.mp4: 480x640 Done. (0.019s)
# video 1/1 (3300/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (3301/3465) /content/video.mp4: 480x640 Done. (0.019s)
# video 1/1 (3302/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3303/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3304/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3305/3465) /content/video.mp4: 480x640 Done. (0.019s)
# video 1/1 (3306/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3307/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3308/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3309/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3310/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3311/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3312/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3313/3465) /content/video.mp4: 480x640 Done. (0.019s)
# video 1/1 (3314/3465) /content/video.mp4: 480x640 Done. (0.019s)
# video 1/1 (3315/3465) /content/video.mp4: 480x640 Done. (0.019s)
# video 1/1 (3316/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3317/3465) /content/video.mp4: 480x640 Done. (0.019s)
# video 1/1 (3318/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3319/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3320/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3321/3465) /content/video.mp4: 480x640 Done. (0.019s)
# video 1/1 (3322/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3323/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3324/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3325/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3326/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3327/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3328/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3329/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3330/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3331/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3332/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3333/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3334/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3335/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3336/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3337/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3338/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3339/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3340/3465) /content/video.mp4: 480x640 Done. (0.024s)
# video 1/1 (3341/3465) /content/video.mp4: 480x640 Done. (0.019s)
# video 1/1 (3342/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3343/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3344/3465) /content/video.mp4: 480x640 Done. (0.019s)
# video 1/1 (3345/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3346/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3347/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3348/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3349/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3350/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3351/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3352/3465) /content/video.mp4: 480x640 Done. (0.019s)
# video 1/1 (3353/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3354/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3355/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3356/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3357/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3358/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3359/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3360/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3361/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3362/3465) /content/video.mp4: 480x640 1 helmet, Done. (0.020s)
# video 1/1 (3363/3465) /content/video.mp4: 480x640 1 helmet, Done. (0.019s)
# video 1/1 (3364/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3365/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3366/3465) /content/video.mp4: 480x640 Done. (0.019s)
# video 1/1 (3367/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3368/3465) /content/video.mp4: 480x640 Done. (0.019s)
# video 1/1 (3369/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3370/3465) /content/video.mp4: 480x640 Done. (0.019s)
# video 1/1 (3371/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3372/3465) /content/video.mp4: 480x640 Done. (0.019s)
# video 1/1 (3373/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3374/3465) /content/video.mp4: 480x640 Done. (0.019s)
# video 1/1 (3375/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3376/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3377/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3378/3465) /content/video.mp4: 480x640 Done. (0.019s)
# video 1/1 (3379/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3380/3465) /content/video.mp4: 480x640 Done. (0.019s)
# video 1/1 (3381/3465) /content/video.mp4: 480x640 Done. (0.019s)
# video 1/1 (3382/3465) /content/video.mp4: 480x640 Done. (0.019s)
# video 1/1 (3383/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3384/3465) /content/video.mp4: 480x640 Done. (0.019s)
# video 1/1 (3385/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3386/3465) /content/video.mp4: 480x640 Done. (0.018s)
# video 1/1 (3387/3465) /content/video.mp4: 480x640 Done. (0.019s)
# video 1/1 (3388/3465) /content/video.mp4: 480x640 Done. (0.019s)
# video 1/1 (3389/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3390/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3391/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3392/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3393/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3394/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3395/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3396/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3397/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3398/3465) /content/video.mp4: 480x640 Done. (0.019s)
# video 1/1 (3399/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3400/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3401/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3402/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3403/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3404/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3405/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3406/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3407/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3408/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3409/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3410/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3411/3465) /content/video.mp4: 480x640 Done. (0.019s)
# video 1/1 (3412/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3413/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3414/3465) /content/video.mp4: 480x640 1 triples, Done. (0.020s)
# video 1/1 (3415/3465) /content/video.mp4: 480x640 1 triples, Done. (0.020s)
# video 1/1 (3416/3465) /content/video.mp4: 480x640 1 triples, Done. (0.020s)
# video 1/1 (3417/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3418/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3419/3465) /content/video.mp4: 480x640 Done. (0.019s)
# video 1/1 (3420/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (3421/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (3422/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (3423/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (3424/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (3425/3465) /content/video.mp4: 480x640 2 helmets, Done. (0.020s)
# video 1/1 (3426/3465) /content/video.mp4: 480x640 1 helmet, Done. (0.020s)
# video 1/1 (3427/3465) /content/video.mp4: 480x640 1 helmet, Done. (0.020s)
# video 1/1 (3428/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3429/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (3430/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (3431/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.019s)
# video 1/1 (3432/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3433/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (3434/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (3435/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (3436/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (3437/3465) /content/video.mp4: 480x640 1 without_helmet, Done. (0.020s)
# video 1/1 (3438/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3439/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3440/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3441/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3442/3465) /content/video.mp4: 480x640 Done. (0.019s)
# video 1/1 (3443/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3444/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3445/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3446/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3447/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3448/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3449/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3450/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3451/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3452/3465) /content/video.mp4: 480x640 2 helmets, Done. (0.019s)
# video 1/1 (3453/3465) /content/video.mp4: 480x640 Done. (0.020s)
# video 1/1 (3454/3465) /content/video.mp4: 480x640 2 helmets, Done. (0.020s)
# video 1/1 (3455/3465) /content/video.mp4: 480x640 2 helmets, Done. (0.020s)
# video 1/1 (3456/3465) /content/video.mp4: 480x640 2 helmets, Done. (0.019s)
# video 1/1 (3457/3465) /content/video.mp4: 480x640 2 helmets, Done. (0.019s)
# video 1/1 (3458/3465) /content/video.mp4: 480x640 2 helmets, Done. (0.020s)
# video 1/1 (3459/3465) /content/video.mp4: 480x640 2 helmets, Done. (0.020s)
# video 1/1 (3460/3465) /content/video.mp4: 480x640 2 helmets, Done. (0.020s)
# video 1/1 (3461/3465) /content/video.mp4: 480x640 2 helmets, Done. (0.020s)
# video 1/1 (3462/3465) /content/video.mp4: 480x640 2 helmets, Done. (0.020s)
# video 1/1 (3463/3465) /content/video.mp4: 480x640 2 helmets, Done. (0.020s)
# video 1/1 (3464/3465) /content/video.mp4: 480x640 2 helmets, Done. (0.020s)
# video 1/1 (3465/3465) /content/video.mp4: 480x640 2 helmets, Done. (0.020s)
# Speed: 0.4ms pre-process, 19.6ms inference, 1.3ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp3

# %% [markdown]
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <img align="left" src="https://user-images.githubusercontent.com/26833433/127574988-6a558aa1-d268-44b9-bf6b-62d4c605cc72.jpg" width="600">

# %% [markdown]
# # 2. Validate
# Validate a model's accuracy on [COCO](https://cocodataset.org/#home) val or test-dev datasets. Models are downloaded automatically from the [latest YOLOv5 release](https://github.com/ultralytics/yolov5/releases). To show results by class use the `--verbose` flag. Note that `pycocotools` metrics may be ~1% better than the equivalent repo metrics, as is visible below, due to slight differences in mAP computation.

# %%
# !unzip -q ../train_data.zip -d ../

# %% [markdown]
# ## COCO val
# Download [COCO val 2017](https://github.com/ultralytics/yolov5/blob/74b34872fdf41941cddcf243951cdb090fbac17b/data/coco.yaml#L14) dataset (1GB - 5000 images), and test model accuracy.

# %%
# Run YOLOv5x on COCO val
# !python val.py --weights yolov5x.pt --data coco.yaml --img 640 --iou 0.65 --half
# Out:
# val: data=/content/yolov5/data/coco.yaml, weights=['yolov5x.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.65, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=True, project=runs/val, name=exp, exist_ok=False, half=True, dnn=False
# YOLOv5 🚀 v6.1-174-gc4cb7c6 torch 1.11.0+cu113 CUDA:0 (Tesla V100-SXM2-16GB, 16160MiB)
#
# Downloading https://github.com/ultralytics/yolov5/releases/download/v6.1/yolov5x.pt to yolov5x.pt...
# 100% 166M/166M [00:05<00:00, 33.5MB/s]
#
# Fusing layers...
# YOLOv5x summary: 444 layers, 86705005 parameters, 0 gradients
# Downloading https://ultralytics.com/assets/Arial.ttf to /root/.config/Ultralytics/Arial.ttf...
# 100% 755k/755k [00:00<00:00, 49.6MB/s]
# val: Scanning '/content/datasets/coco/val2017' images and labels...4952 found, 48 missing, 0 empty, 0 corrupt: 100% 5000/5000 [00:00<00:00, 10667.19it/s]
# val: New cache created: /content/datasets/coco/val2017.cache
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 157/157 [00:58<00:00,  2.70it/s]
#                  all       5000      36335      0.743      0.626      0.683      0.496
# Speed: 0.1ms pre-process, 4.8ms inference, 1.2ms NMS per image at shape (32, 3, 640, 640)
#
# Evaluating pycocotools mAP... saving runs/val/exp/yolov5x_predictions.json...
# loading annotations into memory...
# Done (t=0.38s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=5.42s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=72.67s).
# Accumulating evaluation results...
# DONE (t=13.48s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.506
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.688
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.549
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.340
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.557
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.651
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.382
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.631
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.684
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.528
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.737
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.833
# Results saved to runs/val/exp

# %% [markdown]
# ## COCO test
# Download [COCO test2017](https://github.com/ultralytics/yolov5/blob/74b34872fdf41941cddcf243951cdb090fbac17b/data/coco.yaml#L15) dataset (7GB - 40,000 images), to test model accuracy on test-dev set (**20,000 images, no labels**). Results are saved to a `*.json` file which should be **zipped** and submitted to the evaluation server at https://competitions.codalab.org/competitions/20794.

# %%
# Download COCO test-dev2017
torch.hub.download_url_to_file('https://ultralytics.com/assets/coco2017labels.zip', 'tmp.zip')
# !unzip -q tmp.zip -d ../datasets && rm tmp.zip
# !f="test2017.zip" && curl http://images.cocodataset.org/zips/$f -o $f && unzip -q $f -d ../datasets/coco/images

# %%
# Run YOLOv5x on COCO test
# !python val.py --weights yolov5x.pt --data coco.yaml --img 640 --iou 0.65 --half --task test

# %% [markdown]
# # 3. Train
#
# <p align=""><a href="https://roboflow.com/?ref=ultralytics"><img width="1000" src="https://uploads-ssl.webflow.com/5f6bc60e665f54545a1e52a5/615627e5824c9c6195abfda9_computer-vision-cycle.png"/></a></p>
# Close the active learning loop by sampling images from your inference conditions with the `roboflow` pip package
# <br><br>
#
# Train a YOLOv5s model on the [COCO128](https://www.kaggle.com/ultralytics/coco128) dataset with `--data coco128.yaml`, starting from pretrained `--weights yolov5s.pt`, or from randomly initialized `--weights '' --cfg yolov5s.yaml`.
#
# - **Pretrained [Models](https://github.com/ultralytics/yolov5/tree/master/models)** are downloaded
# automatically from the [latest YOLOv5 release](https://github.com/ultralytics/yolov5/releases)
# - **[Datasets](https://github.com/ultralytics/yolov5/tree/master/data)** available for autodownload include: [COCO](https://github.com/ultralytics/yolov5/blob/master/data/coco.yaml), [COCO128](https://github.com/ultralytics/yolov5/blob/master/data/coco128.yaml), [VOC](https://github.com/ultralytics/yolov5/blob/master/data/VOC.yaml), [Argoverse](https://github.com/ultralytics/yolov5/blob/master/data/Argoverse.yaml), [VisDrone](https://github.com/ultralytics/yolov5/blob/master/data/VisDrone.yaml), [GlobalWheat](https://github.com/ultralytics/yolov5/blob/master/data/GlobalWheat2020.yaml), [xView](https://github.com/ultralytics/yolov5/blob/master/data/xView.yaml), [Objects365](https://github.com/ultralytics/yolov5/blob/master/data/Objects365.yaml), [SKU-110K](https://github.com/ultralytics/yolov5/blob/master/data/SKU-110K.yaml).
# - **Training Results** are saved to `runs/train/` with incrementing run directories, i.e. `runs/train/exp2`, `runs/train/exp3` etc.
# <br><br>
#
# ## Train on Custom Data with Roboflow 🌟 NEW
#
# [Roboflow](https://roboflow.com/?ref=ultralytics) enables you to easily **organize, label, and prepare** a high quality dataset with your own custom data. Roboflow also makes it easy to establish an active learning pipeline, collaborate with your team on dataset improvement, and integrate directly into your model building workflow with the `roboflow` pip package.
#
# - Custom Training Example: [https://blog.roboflow.com/how-to-train-yolov5-on-a-custom-dataset/](https://blog.roboflow.com/how-to-train-yolov5-on-a-custom-dataset/?ref=ultralytics)
# - Custom Training Notebook: [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/roboflow-ai/yolov5-custom-training-tutorial/blob/main/yolov5-custom-training.ipynb)
# <br>
#
# <p align=""><a href="https://roboflow.com/?ref=ultralytics"><img width="480" src="https://uploads-ssl.webflow.com/5f6bc60e665f54545a1e52a5/6152a275ad4b4ac20cd2e21a_roboflow-annotate.gif"/></a></p>Label images lightning fast (including with model-assisted labeling)

# %%
# Tensorboard  (optional)
# %load_ext tensorboard
# %tensorboard --logdir runs/train

# %%
# Weights & Biases  (optional)
# %pip install -q wandb
import wandb
wandb.login()

# %%
# Train YOLOv5s on COCO128 for 3 epochs
# !python train.py --img 640 --batch 3 --epochs 60 --data custom_dataset.yaml --weights yolov5s.pt --cache
# Out:
# train: weights=yolov5s.pt, cfg=, data=custom_dataset.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=60, batch_size=3, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.1-177-gd059d1d torch 1.11.0+cu113 CUDA:0 (Tesla K80, 11441MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# Weights & Biases: run 'pip install wandb' to automatically track and visualize YOLOv5 🚀 runs (RECOMMENDED)
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# Downloading https://ultralytics.com/assets/Arial.ttf to /root/.config/Ultralytics/Arial.ttf...
# 100% 755k/755k [00:00<00:00, 18.8MB/s]
# Downloading https://github.com/ultralytics/yolov5/releases/download/v6.0/yolov5s.pt to yolov5s.pt...
# 100% 14.0M/14.0M [00:00<00:00, 115MB/s]
#
# Overriding model.yaml nc=80 with nc=3
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Conv                      [3, 32, 6, 2, 2]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  2    115712  models.common.C3                        [128, 128, 2]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  3    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1   1182720  models.common.C3                        [512, 512, 1]
#   9                -1  1    656896  models.common.SPPF                      [512, 512, 5]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1     21576  models.yolo.Detect                      [3, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# Model summary: 270 layers, 7027720 parameters, 7027720 gradients, 15.9 GFLOPs
#
# Transferred 343/349 items from yolov5s.pt
# Scaled weight_decay = 0.0004921875
# optimizer: SGD with parameter groups 57 weight (no decay), 60 weight, 60 bias
# albumentations: version 1.0.3 required by YOLOv5, but version 0.1.12 is currently installed
# train: Scanning '/content/yolov5/../train_data/labels/train' images and labels...120 found, 0 missing, 0 empty, 0 corrupt: 100% 120/120 [00:00<00:00, 371.35it/s]
# train: New cache created: /content/yolov5/../train_data/labels/train.cache
# train: Caching images (0.1GB ram): 100% 120/120 [00:00<00:00, 414.75it/s]
# val: Scanning '/content/yolov5/../train_data/labels/val' images and labels...36 found, 0 missing, 0 empty, 0 corrupt: 100% 36/36 [00:00<00:00, 268.43it/s]
# val: New cache created: /content/yolov5/../train_data/labels/val.cache
# val: Caching images (0.0GB ram): 100% 36/36 [00:00<00:00, 235.69it/s]
# Plotting labels to runs/train/exp/labels.jpg...
#
# AutoAnchor: 5.49 anchors/target, 0.996 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to runs/train/exp
# Starting training for 60 epochs...
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       0/59    0.684G    0.1082     0.066      0.04        48       640: 100% 40/40 [00:18<00:00,  2.20it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 6/6 [00:01<00:00,  5.84it/s]
#                  all         36        135     0.0119       0.39     0.0102    0.00227
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       1/59    0.948G   0.09296   0.07058   0.03577        23       640: 100% 40/40 [00:15<00:00,  2.57it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 6/6 [00:00<00:00,  6.84it/s]
#                  all         36        135     0.0584      0.105     0.0436    0.00925
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       2/59    0.948G   0.08803   0.07036   0.03153        30       640: 100% 40/40 [00:15<00:00,  2.55it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 6/6 [00:00<00:00,  6.98it/s]
#                  all         36        135      0.392      0.264     0.0585     0.0113
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       3/59    0.948G    0.1003    0.0523   0.02966        19       640: 100% 40/40 [00:15<00:00,  2.54it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 6/6 [00:00<00:00,  7.17it/s]
#                  all         36        135      0.405      0.119     0.0384    0.00693
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       4/59    0.948G    0.1081    0.0437   0.02935        28       640: 100% 40/40 [00:15<00:00,  2.54it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 6/6 [00:00<00:00,  7.94it/s]
#                  all         36        135      0.261       0.44      0.248       0.08
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       5/59    0.948G    0.1047   0.04656   0.02859        45       640: 100% 40/40 [00:15<00:00,  2.53it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 6/6 [00:00<00:00,  7.94it/s]
#                  all         36        135      0.274      0.365      0.256     0.0709
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       6/59    0.948G    0.1006   0.05025   0.02743        33       640: 100% 40/40 [00:15<00:00,  2.54it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 6/6 [00:00<00:00,  8.23it/s]
#                  all         36        135      0.542      0.274      0.167     0.0344
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       7/59    0.948G   0.09517   0.04812   0.02693        27       640: 100% 40/40 [00:15<00:00,  2.55it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 6/6 [00:00<00:00,  8.26it/s]
#                  all         36        135      0.295      0.457      0.323      0.114
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       8/59    0.948G    0.0916   0.05313   0.02524        29       640: 100% 40/40 [00:15<00:00,  2.54it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 6/6 [00:00<00:00,  8.37it/s]
#                  all         36        135      0.233      0.528      0.301     0.0845
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       9/59    0.948G   0.08816   0.05625   0.02623        21       640: 100% 40/40 [00:15<00:00,  2.54it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 6/6 [00:00<00:00,  8.29it/s]
#                  all         36        135      0.302      0.378      0.304      0.135
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      10/59    0.948G   0.09361   0.05082   0.02647        20       640: 100% 40/40 [00:15<00:00,  2.52it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 6/6 [00:00<00:00,  8.29it/s]
#                  all         36        135      0.303      0.369      0.269      0.102
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      11/59    0.948G   0.08588    0.0542    0.0249        21       640: 100% 40/40 [00:15<00:00,  2.52it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 6/6 [00:00<00:00,  8.36it/s]
#                  all         36        135      0.793      0.268      0.363      0.133
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      12/59    0.948G   0.08616   0.05603   0.02403         8       640: 100% 40/40 [00:15<00:00,  2.52it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 6/6 [00:00<00:00,  8.31it/s]
#                  all         36        135       0.67      0.322      0.354      0.142
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      13/59    0.948G   0.07923   0.05235   0.02414        44       640: 100% 40/40 [00:15<00:00,  2.52it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 6/6 [00:00<00:00,  8.23it/s]
#                  all         36        135      0.583      0.413      0.376      0.155
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      14/59    0.948G   0.08211   0.05719   0.02367        29       640: 100% 40/40 [00:15<00:00,  2.53it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 6/6 [00:00<00:00,  8.32it/s]
#                  all         36        135      0.636      0.437      0.338      0.162
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      15/59    0.948G   0.08096   0.05399   0.02341        19       640: 100% 40/40 [00:15<00:00,  2.52it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 6/6 [00:00<00:00,  8.21it/s]
#                  all         36        135      0.679      0.373      0.384      0.162
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      16/59    0.948G   0.08063   0.05676   0.02341        37       640: 100% 40/40 [00:15<00:00,  2.52it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 6/6 [00:00<00:00,  8.40it/s]
#                  all         36        135      0.621      0.486      0.397      0.161
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      17/59    0.948G   0.07333   0.06031   0.02196        23       640: 100% 40/40 [00:15<00:00,  2.51it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 6/6 [00:00<00:00,  8.48it/s]
#                  all         36        135      0.771       0.43      0.493      0.193
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      18/59    0.948G   0.07063   0.05427   0.02064        27       640: 100% 40/40 [00:15<00:00,  2.52it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 6/6 [00:00<00:00,  8.33it/s]
#                  all         36        135      0.752      0.396       0.45      0.185
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      19/59    0.948G   0.06982   0.05447      0.02        25       640: 100% 40/40 [00:15<00:00,  2.53it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 6/6 [00:00<00:00,  8.45it/s]
#                  all         36        135      0.365      0.715      0.521      0.184
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      20/59    0.948G   0.07007   0.05096   0.02034        23       640: 100% 40/40 [00:15<00:00,  2.53it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 6/6 [00:00<00:00,  8.32it/s]
#                  all         36        135      0.358      0.601      0.454       0.17
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      21/59    0.948G   0.07229   0.05366   0.01944        18       640: 100% 40/40 [00:15<00:00,  2.52it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 6/6 [00:00<00:00,  8.30it/s]
#                  all         36        135      0.395      0.643      0.519      0.157
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      22/59    0.948G   0.07158   0.05397   0.01768        40       640: 100% 40/40 [00:15<00:00,  2.53it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 6/6 [00:00<00:00,  8.57it/s]
#                  all         36        135      0.414       0.61      0.503      0.198
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      23/59    0.948G   0.06904   0.04932   0.01794        17       640: 100% 40/40 [00:15<00:00,  2.53it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 6/6 [00:00<00:00,  8.59it/s]
#                  all         36        135      0.583       0.65      0.592      0.216
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      24/59    0.948G   0.07269   0.05352   0.01643        17       640: 100% 40/40 [00:15<00:00,  2.51it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 6/6 [00:00<00:00,  8.19it/s]
#                  all         36        135       0.46      0.509      0.446      0.189
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      25/59    0.948G   0.07243   0.05484   0.01574        18       640: 100% 40/40 [00:15<00:00,  2.51it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 6/6 [00:00<00:00,  8.42it/s]
#                  all         36        135      0.706      0.664      0.639      0.232
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      26/59    0.948G   0.07381   0.05237   0.01738        32       640: 100% 40/40 [00:15<00:00,  2.52it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 6/6 [00:00<00:00,  8.33it/s]
#                  all         36        135      0.409      0.658      0.459      0.178
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      27/59    0.948G   0.06891   0.05224   0.01437        25       640: 100% 40/40 [00:15<00:00,  2.52it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 6/6 [00:00<00:00,  8.44it/s]
#                  all         36        135      0.773      0.701       0.68       0.26
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      28/59    0.948G   0.06667   0.05138   0.01339        16       640: 100% 40/40 [00:15<00:00,  2.51it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 6/6 [00:00<00:00,  8.49it/s]
#                  all         36        135      0.746      0.694      0.688      0.259
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      29/59    0.948G   0.06725   0.05554   0.01326        20       640: 100% 40/40 [00:15<00:00,  2.51it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 6/6 [00:00<00:00,  8.58it/s]
#                  all         36        135      0.677      0.749       0.69      0.287
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      30/59    0.948G   0.06595   0.05188    0.0131        53       640: 100% 40/40 [00:15<00:00,  2.51it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 6/6 [00:00<00:00,  8.32it/s]
#                  all         36        135      0.796      0.732      0.753      0.294
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      31/59    0.948G   0.06611   0.05386   0.01241        33       640: 100% 40/40 [00:15<00:00,  2.51it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 6/6 [00:00<00:00,  8.37it/s]
#                  all         36        135      0.794      0.716       0.72      0.275
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      32/59    0.948G   0.06281   0.05004   0.01193        40       640: 100% 40/40 [00:15<00:00,  2.52it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 6/6 [00:00<00:00,  8.40it/s]
#                  all         36        135      0.765      0.692      0.684      0.257
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      33/59    0.948G   0.06578   0.04964   0.01222        19       640: 100% 40/40 [00:15<00:00,  2.52it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 6/6 [00:00<00:00,  8.42it/s]
#                  all         36        135      0.732      0.698      0.676      0.259
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      34/59    0.948G   0.06621   0.05284  0.009358        22       640: 100% 40/40 [00:15<00:00,  2.51it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 6/6 [00:00<00:00,  8.54it/s]
#                  all         36        135      0.521      0.605      0.486      0.192
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      35/59    0.948G   0.06782   0.04947   0.01059        36       640: 100% 40/40 [00:15<00:00,  2.50it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 6/6 [00:00<00:00,  8.53it/s]
#                  all         36        135      0.696      0.677      0.673      0.252
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      36/59    0.948G   0.06623   0.05018   0.01036        22       640: 100% 40/40 [00:15<00:00,  2.51it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 6/6 [00:00<00:00,  8.54it/s]
#                  all         36        135      0.621      0.726      0.599       0.24
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      37/59    0.948G   0.06321   0.04915  0.009253        17       640: 100% 40/40 [00:15<00:00,  2.51it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 6/6 [00:00<00:00,  8.30it/s]
#                  all         36        135      0.793      0.686      0.718      0.287
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      38/59    0.948G   0.06468   0.04834   0.01105        30       640: 100% 40/40 [00:15<00:00,  2.52it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 6/6 [00:00<00:00,  8.38it/s]
#                  all         36        135      0.633      0.613      0.552      0.231
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      39/59    0.948G   0.06322   0.05236  0.009789        24       640: 100% 40/40 [00:15<00:00,  2.52it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 6/6 [00:00<00:00,  8.50it/s]
#                  all         36        135      0.771      0.702      0.688      0.259
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      40/59    0.948G   0.06259   0.05158  0.009039        16       640: 100% 40/40 [00:15<00:00,  2.52it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 6/6 [00:00<00:00,  8.61it/s]
#                  all         36        135      0.745      0.724      0.693      0.272
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      41/59    0.948G   0.06338    0.0499   0.01003        25       640: 100% 40/40 [00:15<00:00,  2.53it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 6/6 [00:00<00:00,  8.52it/s]
#                  all         36        135       0.77      0.725      0.705      0.273
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      42/59    0.948G   0.06281   0.05199  0.009594        35       640: 100% 40/40 [00:15<00:00,  2.54it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 6/6 [00:00<00:00,  8.51it/s]
#                  all         36        135      0.717      0.673      0.619      0.255
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      43/59    0.948G   0.06267   0.05185  0.008791        30       640: 100% 40/40 [00:15<00:00,  2.55it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 6/6 [00:00<00:00,  8.27it/s]
#                  all         36        135       0.75       0.71      0.647      0.263
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      44/59    0.948G   0.06275   0.05325  0.008186        39       640: 100% 40/40 [00:15<00:00,  2.54it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 6/6 [00:00<00:00,  8.74it/s]
#                  all         36        135      0.752      0.722       0.67      0.259
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      45/59    0.948G   0.05973   0.04698  0.009573        14       640: 100% 40/40 [00:15<00:00,  2.55it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 6/6 [00:00<00:00,  8.75it/s]
#                  all         36        135      0.721      0.718      0.665      0.258
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      46/59    0.948G   0.05925   0.04856  0.008598        29       640: 100% 40/40 [00:15<00:00,  2.55it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 6/6 [00:00<00:00,  8.53it/s]
#                  all         36        135      0.731      0.733      0.678      0.248
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      47/59    0.948G   0.05957   0.05079  0.007368        30       640: 100% 40/40 [00:15<00:00,  2.53it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 6/6 [00:00<00:00,  8.67it/s]
#                  all         36        135      0.688      0.684       0.61       0.24
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      48/59    0.948G   0.05935   0.04926  0.008368        27       640: 100% 40/40 [00:15<00:00,  2.55it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 6/6 [00:00<00:00,  8.65it/s]
#                  all         36        135      0.773      0.684        0.7      0.273
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      49/59    0.948G   0.06297   0.05194  0.008614        15       640: 100% 40/40 [00:15<00:00,  2.55it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 6/6 [00:00<00:00,  8.66it/s]
#                  all         36        135      0.682      0.631      0.576      0.246
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      50/59    0.948G   0.05995   0.05468   0.00707        25       640: 100% 40/40 [00:15<00:00,  2.55it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 6/6 [00:00<00:00,  8.55it/s]
#                  all         36        135      0.748      0.669      0.654      0.257
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      51/59    0.948G   0.05849   0.05367  0.007662        19       640: 100% 40/40 [00:15<00:00,  2.55it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 6/6 [00:00<00:00,  8.69it/s]
#                  all         36        135      0.719      0.733      0.691      0.274
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      52/59    0.948G   0.05955   0.05567  0.007803        32       640: 100% 40/40 [00:15<00:00,  2.54it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 6/6 [00:00<00:00,  8.62it/s]
#                  all         36        135      0.756      0.728      0.714      0.268
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      53/59    0.948G   0.05848   0.05498  0.007645        23       640: 100% 40/40 [00:15<00:00,  2.55it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 6/6 [00:00<00:00,  8.65it/s]
#                  all         36        135      0.764      0.728       0.72      0.275
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      54/59    0.948G     0.058   0.05756  0.006722        23       640: 100% 40/40 [00:15<00:00,  2.55it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 6/6 [00:00<00:00,  8.79it/s]
#                  all         36        135      0.749      0.729      0.696      0.277
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      55/59    0.948G   0.05633   0.05244  0.007186        27       640: 100% 40/40 [00:15<00:00,  2.54it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 6/6 [00:00<00:00,  8.47it/s]
#                  all         36        135      0.773      0.748      0.725      0.273
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      56/59    0.948G   0.05721   0.05335  0.008883        27       640: 100% 40/40 [00:15<00:00,  2.55it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 6/6 [00:00<00:00,  8.36it/s]
#                  all         36        135      0.779      0.757      0.745      0.278
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      57/59    0.948G   0.05595   0.04962  0.008065        20       640: 100% 40/40 [00:15<00:00,  2.54it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 6/6 [00:00<00:00,  8.60it/s]
#                  all         36        135      0.792      0.759       0.74      0.279
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      58/59    0.948G   0.05654   0.05096  0.007559        16       640: 100% 40/40 [00:15<00:00,  2.54it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 6/6 [00:00<00:00,  8.28it/s]
#                  all         36        135        0.8      0.756      0.742       0.28
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      59/59    0.948G   0.05673   0.05328  0.007375        34       640: 100% 40/40 [00:15<00:00,  2.55it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 6/6 [00:00<00:00,  8.63it/s]
#                  all         36        135      0.805      0.702      0.697      0.278
#
# 60 epochs completed in 0.287 hours.
# Optimizer stripped from runs/train/exp/weights/last.pt, 14.5MB
# Optimizer stripped from runs/train/exp/weights/best.pt, 14.5MB
#
# Validating runs/train/exp/weights/best.pt...
# Fusing layers...
# Model summary: 213 layers, 7018216 parameters, 0 gradients, 15.8 GFLOPs
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 6/6 [00:01<00:00,  3.47it/s]
#                  all         36        135      0.796      0.732      0.754      0.295
#               helmet         36         30      0.819        0.7      0.723      0.186
#       without_helmet         36         85       0.57      0.647      0.597      0.164
#              triples         36         20          1       0.85      0.941      0.536
# Results saved to runs/train/exp

# %% [markdown]
# # 4. Visualize

# %% [markdown]
# ## Weights & Biases Logging 🌟 NEW
#
# [Weights & Biases](https://wandb.ai/site?utm_campaign=repo_yolo_notebook) (W&B) is now integrated with YOLOv5 for real-time visualization and cloud logging of training runs. This allows for better run comparison and introspection, as well improved visibility and collaboration for teams. To enable W&B `pip install wandb`, and then train normally (you will be guided through setup on first use).
#
# During training you will see live updates at [https://wandb.ai/home](https://wandb.ai/home?utm_campaign=repo_yolo_notebook), and you can create and share detailed [Reports](https://wandb.ai/glenn-jocher/yolov5_tutorial/reports/YOLOv5-COCO128-Tutorial-Results--VmlldzozMDI5OTY) of your results. For more information see the [YOLOv5 Weights & Biases Tutorial](https://github.com/ultralytics/yolov5/issues/1289).
#
# <p align="left"><img width="900" alt="Weights & Biases dashboard" src="https://user-images.githubusercontent.com/26833433/135390767-c28b050f-8455-4004-adb0-3b730386e2b2.png"></p>

# %% [markdown]
# ## Local Logging
#
# All results are logged by default to `runs/train`, with a new experiment directory created for each new training as `runs/train/exp2`, `runs/train/exp3`, etc. View train and val jpgs to see mosaics, labels, predictions and augmentation effects. Note an Ultralytics **Mosaic Dataloader** is used for training (shown below), which combines 4 images into 1 mosaic during training.
#
# > <img src="https://user-images.githubusercontent.com/26833433/131255960-b536647f-7c61-4f60-bbc5-cb2544d71b2a.jpg" width="700">
# `train_batch0.jpg` shows train batch 0 mosaics and labels
#
# > <img src="https://user-images.githubusercontent.com/26833433/131256748-603cafc7-55d1-4e58-ab26-83657761aed9.jpg" width="700">
# `test_batch0_labels.jpg` shows val batch 0 labels
#
# > <img src="https://user-images.githubusercontent.com/26833433/131256752-3f25d7a5-7b0f-4bb3-ab78-46343c3800fe.jpg" width="700">
# `test_batch0_pred.jpg` shows val batch 0 _predictions_
#
# Training results are automatically logged to [Tensorboard](https://www.tensorflow.org/tensorboard) and [CSV](https://github.com/ultralytics/yolov5/pull/4148) as `results.csv`, which is plotted as `results.png` (below) after training completes. You can also plot any `results.csv` file manually:
#
# ```python
# from utils.plots import plot_results
# plot_results('path/to/results.csv')  # plot 'results.csv' as 'results.png'
# ```
#
# <img align="left" width="800" alt="COCO128 Training Results" src="https://user-images.githubusercontent.com/26833433/126906780-8c5e2990-6116-4de6-b78a-367244a33ccf.png">

# %% [markdown]
# # Environments
#
# YOLOv5 may be run in any of the following up-to-date verified environments (with all dependencies including [CUDA](https://developer.nvidia.com/cuda)/[CUDNN](https://developer.nvidia.com/cudnn), [Python](https://www.python.org/) and [PyTorch](https://pytorch.org/) preinstalled):
#
# - **Google Colab and Kaggle** notebooks with free GPU: <a href="https://colab.research.google.com/github/ultralytics/yolov5/blob/master/tutorial.ipynb"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"></a> <a href="https://www.kaggle.com/ultralytics/yolov5"><img src="https://kaggle.com/static/images/open-in-kaggle.svg" alt="Open In Kaggle"></a>
# - **Google Cloud** Deep Learning VM. See [GCP Quickstart Guide](https://github.com/ultralytics/yolov5/wiki/GCP-Quickstart)
# - **Amazon** Deep Learning AMI. See [AWS Quickstart Guide](https://github.com/ultralytics/yolov5/wiki/AWS-Quickstart)
# - **Docker Image**. See [Docker Quickstart Guide](https://github.com/ultralytics/yolov5/wiki/Docker-Quickstart) <a href="https://hub.docker.com/r/ultralytics/yolov5"><img src="https://img.shields.io/docker/pulls/ultralytics/yolov5?logo=docker" alt="Docker Pulls"></a>

# %% [markdown]
# # Status
#
# ![CI CPU testing](https://github.com/ultralytics/yolov5/workflows/CI%20CPU%20testing/badge.svg)
#
# If this badge is green, all [YOLOv5 GitHub Actions](https://github.com/ultralytics/yolov5/actions) Continuous Integration (CI) tests are currently passing. CI tests verify correct operation of YOLOv5 training ([train.py](https://github.com/ultralytics/yolov5/blob/master/train.py)), testing ([val.py](https://github.com/ultralytics/yolov5/blob/master/val.py)), inference ([detect.py](https://github.com/ultralytics/yolov5/blob/master/detect.py)) and export ([export.py](https://github.com/ultralytics/yolov5/blob/master/export.py)) on macOS, Windows, and Ubuntu every 24 hours and on every commit.

# %% [markdown]
# # Appendix
#
# Optional extras below. Unit tests validate repo functionality and should be run on any PRs submitted.

# %%
# Reproduce
for x in 'yolov5n', 'yolov5s', 'yolov5m', 'yolov5l', 'yolov5x':
  # !python val.py --weights {x}.pt --data coco.yaml --img 640 --task speed  # speed
  # !python val.py --weights {x}.pt --data coco.yaml --img 640 --conf 0.001 --iou 0.65  # mAP

# %%
# PyTorch Hub
import torch

# Model
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')

# Images
dir = 'https://ultralytics.com/images/'
imgs = [dir + f for f in ('zidane.jpg', 'bus.jpg')]  # batch of images

# Inference
results = model(imgs)
results.print()  # or .show(), .save()

# %%
# CI Checks
# %%shell
export PYTHONPATH="$PWD"  # to run *.py. files in subdirectories
rm -rf runs  # remove runs/
for m in yolov5n; do  # models
  python train.py --img 64 --batch 32 --weights $m.pt --epochs 1 --device 0  # train pretrained
  python train.py --img 64 --batch 32 --weights '' --cfg $m.yaml --epochs 1 --device 0  # train scratch
  for d in 0 cpu; do  # devices
    python val.py --weights $m.pt --device $d # val official
    python val.py --weights runs/train/exp/weights/best.pt --device $d # val custom
    python detect.py --weights $m.pt --device $d  # detect official
    python detect.py --weights runs/train/exp/weights/best.pt --device $d  # detect custom
  done
  python hubconf.py  # hub
  python models/yolo.py --cfg $m.yaml  # build PyTorch model
  python models/tf.py --weights $m.pt  # build TensorFlow model
  python export.py --img 64 --batch 1 --weights $m.pt --include torchscript onnx  # export
done

# %%
# Profile
from utils.torch_utils import profile

m1 = lambda x: x * torch.sigmoid(x)
m2 = torch.nn.SiLU()
results = profile(input=torch.randn(16, 3, 640, 640), ops=[m1, m2], n=100)

# %%
# Evolve
# !python train.py --img 640 --batch 64 --epochs 100 --data coco128.yaml --weights yolov5s.pt --cache --noautoanchor --evolve
# !d=runs/train/evolve && cp evolve.* $d && zip -r evolve.zip $d && gsutil mv evolve.zip gs://bucket  # upload results (optional)

# %%
# VOC
for b, m in zip([64, 64, 64, 32, 16], ['yolov5n', 'yolov5s', 'yolov5m', 'yolov5l', 'yolov5x']):  # batch, model
  # !python train.py --batch {b} --weights {m}.pt --data VOC.yaml --epochs 50 --img 512 --hyp hyp.VOC.yaml --project VOC --name {m} --cache

# %%
# TensorRT 
# https://docs.nvidia.com/deeplearning/tensorrt/install-guide/index.html#installing-pip
# !pip install -U nvidia-tensorrt --index-url https://pypi.ngc.nvidia.com  # install
# !python export.py --weights yolov5s.pt --include engine --imgsz 640 640 --device 0  # export
# !python detect.py --weights yolov5s.engine --imgsz 640 640 --device 0  # inference
